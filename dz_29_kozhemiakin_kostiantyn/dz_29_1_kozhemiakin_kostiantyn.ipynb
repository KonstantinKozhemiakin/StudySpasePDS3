# %% [markdown]
# # 1.
#
# x |0-24|24-48|48-72|72-96|96-120|120-144|144-168|168-192|192-216
# :-:|:-|:-|:-|:-|:-|:-|:-|:-|:-:
# n | 1| 2|4 |6 |12 |16 |6  |2  | 1
#
# H0 - вибірка має нормальний розподіл ознаки генеральної сукупності
#
# H1 - вибірка не має нормального розподілу ознаки генеральної сукупності

# %% [markdown]
# xi |12|36|60|84|108|132|156|180|204
# :-:|:-|:-|:-|:-|:--|:--|:--|:--|:-:
# ni | 1| 2|4 |6 |12 |16 |6  |2  | 1

# %%
n = 1+2+4+6+12+16+6+2+1
print("n: ", n)
x_avg = (12*1 + 36*2 + 60*4 + 84*6 + 108*12 + 132*16 + 156*6 + 180*2 + 204*1) / n
print("Вибіркове середнє: ", x_avg)
d_x = 1 / n * (12 ** 2 * 1  + 36 ** 2 * 2 + 60 ** 2 * 4 + 84 ** 2 * 6 + 108 ** 2 * 12 + 132 ** 2 * 16 + 156 ** 2 * 6 + 180 ** 2 * 2 + 204 ** 2 * 1) - x_avg ** 2
print("Вибіркова дисперсія: ", d_x)
s_d = d_x **0.5
print("Вибіркове стандартне квадратичне відхилення: ", s_d)
# Out:
# n:  50
# Вибіркове середнє:  114.72
# Вибіркова дисперсія:  1452.441600000002
# Вибіркове стандартне квадратичне відхилення:  38.1109118232561

# %% [markdown]
# i  | (Zi-1;Zi) | Ф(Zi-1)| Ф(Zi) |   pi |ni=50pi
# :-:|:-------   |:------ |:----  |:---- |:-----:
#  1 |  -∞; -2.38|  -0.5  |-0.4913|0.0087|   1
#  2 |-2.38;-1.75|-0.4913 |-0.4599|0.0314|   2
#  3 |-1.75;-1.12|-0.4599 |-0.3686|0.0913|   5
#  4 |-1.12;-0.49|-0.3686 |-0.1879|0.1807|   9
#  5 |-0.49; 0.14|-0.1879 | 0.0557|0.2436|   12
#  6 | 0.14; 0.77| 0.0557 | 0.2794|0.2237|   11
#  7 | 0.77; 1.40| 0.2794 | 0.4192|0.1398|   7
#  8 | 1.40; 2.08| 0.4192 | 0.4812|0.062 |   3
#  9 | 2.08;  +∞ | 0.4812 | 0.5   |0.0188|   1

# %%
k_emp = (1 - 1) ** 2 / 1 + (2 - 2) ** 2 / 2 + (4 - 5) ** 2 / 5 + (6 - 9) ** 2 / 9 + (12 - 12) ** 2 / 12 + (16 - 11) ** 2 / 11 + (6 - 7) ** 2 / 7 + (2 - 3) ** 2 / 3 + (1 - 1) ** 2 / 1
print("k емпіричне : ", k_emp)
r = 9 - 2 - 1
print("Кількість ступеней свободи : ", r)
k_cr = 16.81
print("k критичне (згідно таблиці) : ", k_cr)
print()
print("Так як к-емпіричне менше к-критичного, нульову гіпотезу не відхиляємо, тобто вибірка має нормальний розподіл")
# Out:
# k емпіричне :  3.948917748917749
# Кількість ступеней свободи :  6
# k критичне (згідно таблиці) :  16.81
#
# Так як к-емпіричне менше к-критичного, нульову гіпотезу не відхиляємо, тобто вибірка має нормальний розподіл

# %% [markdown]
# # 2.

# %% [markdown]
# P(X>=3) = 0.4\
# M(X) = 2
#
# Функція щільності розподілу:\
# f(x) = 0, якщо x < a\
# f(x) = 1 / (b-a), якщо a < x <= b\
# f(x) = 0, якщо x > b\
#
# Формула математичного сподівання:\
# M(X) = ∫<sup>b</sup><sub>a</sub> x / (b-a) dx
#
# ∫<sup>b</sup><sub>3</sub> 1 / (b-a) dx = 0.4\
# ∫<sup>b</sup><sub>a</sub> x / (b-a) dx = 2
#
# x / (b-a) |<sup>b</sup><sub>3</sub> = 0.4\
# x<sup>2</sup> / 2(b-a) |<sup>b</sup><sub>a</sub> = 2
#
# (b-3) / (b-a) = 0.4\
# (b<sup>2</sup> - a<sup>2</sup>) / 2(b-a) = 2
#
# (b-3) / (b-a) = 0.4\
# (b+a) / 2 = 2
#
# 0.6b + 0.4a = 3\
# b = 4 - a
#
# a = -3\
# b = 7
#
# f(x) = 0, якщо x < -3\
# f(x) = 0.1, якщо -3 < x <= 7\
# f(x) = 0, якщо x > 7
