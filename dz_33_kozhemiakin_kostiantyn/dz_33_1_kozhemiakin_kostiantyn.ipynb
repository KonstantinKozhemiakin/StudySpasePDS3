# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_info = pd.read_excel('car_info.xlsx')
car_info
# Out:
#    Марка автомобіля  Вартість  Паливна витрата  Максимальна швидкість  \
# 0               BMW     50000              8.0                    240
# 1            Toyota     25000              6.0                    180
# 2              Ford     30000              7.0                    200
# 3              Audi     60000              9.0                    250
# 4     Mercedes-Benz     70000             10.0                    260
# 5             Honda     20000              5.0                    160
# 6            Nissan     22000              6.0                    170
# 7         Chevrolet     28000              7.5                    190
# 8           Hyundai     18000              5.5                    170
# 9               Kia     22000              6.5                    180
# 10       Volkswagen     26000              7.0                    200
# 11           Subaru     24000              6.5                    190
# ...

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)
ax=fig.add_subplot()
plt.plot(car_info['Вартість'], car_info['Паливна витрата'], linewidth = 2)

# %%
plt.scatter(car_info['Максимальна швидкість'], car_info['Паливна витрата'], color='red', marker='o')

# %%
plt.scatter(car_info['Максимальна швидкість'], car_info['Вантажопідйомність'], marker='o')

# %%
plt.hist(car_info['Максимальна швидкість'], 5, width = 15)
# Out:
# (array([9., 5., 3., 2., 1.]),
#  array([160., 192., 224., 256., 288., 320.]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(x='Марка автомобіля', y='Максимальна швидкість', data=car_info)
# Out:
# <AxesSubplot: xlabel='Марка автомобіля', ylabel='Максимальна швидкість'>

# %%
fig = plt.figure(figsize=(19, 11), dpi=100)
ax=fig.add_subplot()
car_data = pd.read_csv('car details v4.csv')
car_data
sns.boxplot(x='Make', y='Price', data=car_data)
# Out:
# <AxesSubplot: xlabel='Make', ylabel='Price'>

# %%
sb.pairplot(car_info)
