# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('Data_to_Transform.csv')
df.head()
# Out:
#    Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                0.899990              2.895074               11.180748
# 1                1.113554              2.962385               10.842938
# 2                1.156830              2.966378               10.817934
# 3                1.264131              3.000324               10.764570
# 4                1.323914              3.012109               10.753117
#
#    Highly Negative Skew
# 0              9.027485
# 1              9.009762
# 2              9.006134
# 3              9.000125
# 4              8.981296

# %%
df.describe()
# Out:
#        Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# count            10000.000000          10000.000000            10000.000000
# mean                 6.000000              6.000000                6.000000
# std                  2.047237              1.882685                2.045060
# min                  0.899990              2.895074               -6.335679
# 25%                  4.518431              4.614818                4.779235
# 50%                  5.751642              5.634956                6.233932
# 75%                  7.258956              6.924035                7.465319
# max                 16.204517             18.052331               11.180748
#
#        Highly Negative Skew
# count          10000.000000
# mean               6.000000
# std                1.860556
# min               -7.036091
# 25%                5.049961
# 50%                6.360402
# 75%                7.366753
# max                9.027485

# %% [markdown]
# # Moderate Positive Skew

# %%
sns.histplot(df['Moderate Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Moderate Positive Skew'])
df_log10 = np.log10(df['Moderate Positive Skew'])
data = df['Moderate Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_box_cox = pt.fit_transform(data)

# %%
sns.histplot(df_log)
fig_1 = plt.figure()
sns.histplot(df_log10)
fig_2 = plt.figure()
sns.histplot(df_box_cox)
fig_3 = plt.figure()

# %%
fig_1 = sm.qqplot(df['Moderate Positive Skew'], line='45')
plt.show()
fig_2 = sm.qqplot(df_log, line='45')
plt.show()
fig_3 = sm.qqplot(df_log10, line='45')
plt.show()
fig_4 = sm.qqplot(df_box_cox, line='45')
plt.show()

# %% [markdown]
# # Highly Positive Skew

# %%
sns.histplot(df['Highly Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Highly Positive Skew'])
df_log10 = np.log10(df['Highly Positive Skew'])
data = df['Highly Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_box_cox = pt.fit_transform(data)

# %%
sns.histplot(df_log)
fig_1 = plt.figure()
sns.histplot(df_log10)
fig_2 = plt.figure()
sns.histplot(df_box_cox)
fig_3 = plt.figure()

# %%
fig_1 = sm.qqplot(df['Moderate Positive Skew'], line='45')
plt.show()
fig_2 = sm.qqplot(df_log, line='45')
plt.show()
fig_3 = sm.qqplot(df_log10, line='45')
plt.show()
fig_4 = sm.qqplot(df_box_cox, line='45')
plt.show()

# %% [markdown]
# # Moderate Negative Skew

# %%
sns.histplot(df['Moderate Negative Skew'])
fig = plt.figure()

# %%
data = df['Moderate Negative Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='yeo-johnson')
df_yeo_johnson = pt.fit_transform(data)

# %%
sns.histplot(df_yeo_johnson)
fig_1 = plt.figure()
fig_2 = sm.qqplot(df['Moderate Negative Skew'], line='45')
plt.show()
fig_3 = sm.qqplot(df_yeo_johnson, line='45')
plt.show()

# %% [markdown]
# # Highly Negative Skew

# %%
sns.histplot(df['Highly Negative Skew'])
fig = plt.figure()

# %%
data = df['Highly Negative Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='yeo-johnson')
df_yeo_johnson = pt.fit_transform(data)

# %%
sns.histplot(df_yeo_johnson)
fig_1 = plt.figure()
fig_2 = sm.qqplot(df['Highly Negative Skew'], line='45')
plt.show()
fig_3 = sm.qqplot(df_yeo_johnson, line='45')
plt.show()
